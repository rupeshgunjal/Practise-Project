# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv(r"C:\Users\Dell\Downloads\Grades.csv")
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df['EF-303'] = df['EF-303'].fillna(0)

# %%
# Assuming df is your DataFrame
columns_to_fill = ['CY-105', 'HS-105/12', 'MT-111','CS-106',"EL-102",'EE-119','ME-107','ME-107','CS-107','HS-205/20']  # Add the column names you want to fill here

for column in columns_to_fill:
    df[column] = df[column].fillna(0)

# %%
columns_to_fill = ['MT-222', 'EE-222', 'MT-111','MT-224',"CS-210",'CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','MT-442']  # Add the column names you want to fill here

for column in columns_to_fill:
    df[column] = df[column].fillna(0)

# %%
columns_to_fill = ['EL-332', 'CS-318', 'CS-306','CS-306',"CS-312",'CS-317','CS-403','CS-214','CS-421','CS-406','CS-414','CS-419','CS-423','CS-412',]  # Add the column names you want to fill here

for column in columns_to_fill:
    df[column] = df[column].fillna(0)

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
columns_to_encode = ['CY-105', 'HS-105/12', 'MT-111','CS-106',"EL-102",'EE-119','ME-107','ME-107','CS-107','HS-205/20']

for column in columns_to_encode:
    df[column] = df[column].astype(str)
    label_encoder = LabelEncoder()
    df[column] = label_encoder.fit_transform(df[column])

# %%
from sklearn.preprocessing import LabelEncoder
columns_to_encode = ['CS-105','MT-222', 'EE-222', 'MT-111','MT-224',"CS-210",'CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','MT-442']

for column in columns_to_encode:
    df[column] = df[column].astype(str)
    label_encoder = LabelEncoder()
    df[column] = label_encoder.fit_transform(df[column])

# %%
from sklearn.preprocessing import LabelEncoder
columns_to_encode = ['EL-332', 'CS-318', 'CS-306','CS-306',"CS-312",'CS-317','CS-403','CS-214','CS-421','CS-406','CS-414','CS-419','CS-423','CS-412',]

for column in columns_to_encode:
    df[column] = df[column].astype(str)
    label_encoder = LabelEncoder()
    df[column] = label_encoder.fit_transform(df[column])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and columns_to_encode is a list of column names to encode
columns_to_encode = ['CY-105', 'HS-105/12', 'MT-111','CS-106',"EL-102",'EE-119','ME-107','ME-107','CS-107','HS-205/20']  # Add the column names you want to encode here

label_encoder = LabelEncoder()

for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and columns_to_encode is a list of column names to encode
columns_to_encode = ['MT-222', 'EE-222', 'MT-111','MT-224',"CS-210",'CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','MT-442']  # Add the column names you want to encode here

label_encoder = LabelEncoder()

for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and columns_to_encode is a list of column names to encode
columns_to_encode = ['PH-121','HS-101', 'CS-105','EL-332', 'CS-318', 'CS-306','CS-306',"CS-312",'CS-317','CS-403','CS-214','CS-421','CS-406','CS-414','CS-419','CS-423','CS-412',]  # Add the column names you want to encode here

label_encoder = LabelEncoder()

for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001       5      10       9          7      13      10      10
# 1    CS-97002       0       9      11         10      10       6      10
# 2    CS-97003       0       3       1          6       9       0       6
# 3    CS-97004       9       7      11         10       2       2      11
# 4    CS-97005       2       2       3          5       1       0       3
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566  CS-97567       3       0       1          3       6       0       3
# 567  CS-97568       1       0       1          1       1       0       1
# 568  CS-97569       3       0       3          5       1       0       1
# 569  CS-97570       0       4      10          1       2      10       6
# 570  CS-97571       6       9      10          7      11      10       4
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
# Assuming df is your DataFrame and 'Column_to_drop' is the column you want to drop
# Assuming df is your DataFrame
df = df.drop(columns=['Seat No.'])

# %%
X=df.drop('CGPA', axis=1)
Y=df['CGPA']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, Y_train)
# Out:
# 0.8796824189293945

# %%
from sklearn.metrics import r2_score

Y_pred = model.predict(X_test)
r2 = r2_score(Y_test, Y_pred)
print(f"R-squared score: {r2:.3f}")
# Out:
# R-squared score: 0.926

# %%
import seaborn as sns

sns.regplot(x = Y_test, y = Y_pred, color = 'purple', scatter_kws = {'s': 20, 'alpha': 0.5}, line_kws = {'color': 'blue'})
# Out:
# <Axes: xlabel='CGPA'>
